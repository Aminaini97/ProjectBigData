# %% [markdown]
# <a href="https://colab.research.google.com/github/Aminaini97/ProjectBigData/blob/main/crawling_yt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-api-python-client pandas

# %%
from googleapiclient.discovery import build
import pandas as pd
import time

API_KEY = "AIzaSyBpwpNnGp7hTErrbzw7fXDaNAKyWM3IBps"
youtube = build('youtube', 'v3', developerKey=API_KEY)

query = "work life balance OR burnout OR stress kerja OR mental health"
search_response = youtube.search().list(
    q=query,
    part="id,snippet",
    maxResults=30,
    type="video",
    regionCode="ID"
).execute()

video_ids = [item['id']['videoId'] for item in search_response['items']]

comments = []

for vid in video_ids:
    print(f"📥 Ambil komentar dari video: {vid}")
    next_page_token = None

    while True:
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=vid,
                maxResults=100,
                pageToken=next_page_token,
                textFormat="plainText"
            )
            response = request.execute()

            for item in response['items']:
                comment = item['snippet']['topLevelComment']['snippet']
                comments.append({
                    "video_id": vid,
                    "author": comment['authorDisplayName'],
                    "text": comment['textDisplay'],
                    "likeCount": comment['likeCount'],
                    "publishedAt": comment['publishedAt']
                })

            next_page_token = response.get("nextPageToken")
            if not next_page_token:
                break

            time.sleep(0.5)  # biar gak kena rate limit

        except Exception as e:
            print(f"⚠️ Lewati video {vid} karena error: {e}")
            break  # lanjut ke video berikutnya

df = pd.DataFrame(comments)
df.to_csv("youtube_comments_worklifebalance_full.csv", index=False)

print(f"✅ Total komentar disimpan: {len(df)}")
# Out:
# 📥 Ambil komentar dari video: T66oY4tL2co
# 📥 Ambil komentar dari video: G0XUimJbz44
# 📥 Ambil komentar dari video: 4c_xYLwOx-g
# 📥 Ambil komentar dari video: 4FT5RYuifwE
# 📥 Ambil komentar dari video: lxNE909_a5U
# 📥 Ambil komentar dari video: RCUJah0Q70E
# 📥 Ambil komentar dari video: KYHV19ThXaA
# 📥 Ambil komentar dari video: QE8kNh52EeU
# 📥 Ambil komentar dari video: PCBdyvTydG0
# 📥 Ambil komentar dari video: FN0_ow76hU8
# 📥 Ambil komentar dari video: svh5_wkTPK4
# 📥 Ambil komentar dari video: fvj7D2DT1JQ
# 📥 Ambil komentar dari video: Pe2QGeQqXeo
# 📥 Ambil komentar dari video: O0yxJH2i0DE
# 📥 Ambil komentar dari video: Nz9eAaXRzGg
# 📥 Ambil komentar dari video: BpKF-lCxBMQ
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# 📥 Ambil komentar dari video: S31vYAja4Ug
# ...

# %% [markdown]
# cleaning_yt

# %%
pip install Sastrawi
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 4.2 MB/s eta 0:00:00
# ...

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# Tambahkan ini sebelum apply()
factory = StopWordRemoverFactory()
stopword_remover = factory.create_stop_word_remover()

def clean_text(text):
    import re
    if not isinstance(text, str) or not text.strip():
        return ""
    text = text.lower()
    text = re.sub(r'https?://\S+|www\.\S+', '', text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = text.encode('ascii', 'ignore').decode('ascii')
    text = re.sub(r'\s+', ' ', text).strip()
    text = stopword_remover.remove(text)
    return text

df["clean_text"] = df["text"].apply(clean_text)

# Simpan hasil
df.to_csv("youtube_comments_clean.csv", index=False)
print(f"✅ Cleaning selesai! Total data bersih: {len(df)}")
# Out:
# ✅ Cleaning selesai! Total data bersih: 9514

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 33.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 5.1 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17396 sha256=c6f30d8fc16893325ee61866d70ecd629cee4d50e7518a5803d11fa45893f1a3
#   Stored in directory: /root/.cache/pip/wheels/95/0f/04/b17a72024b56a60e499ce1a6313d283ed5ba332407155bee03
# Successfully built googletrans
# ...
#   Attempting uninstall: hyperframe
#     Found existing installation: hyperframe 6.1.0
# ...

# %%
# !pip install deep-translator -q

from deep_translator import GoogleTranslator
import time
import pandas as pd

# Contoh: df["clean_text"] sudah ada dari hasil sebelumnya
# df = pd.read_csv("hasil_clean.csv")

translator = GoogleTranslator(source='id', target='en')

def batch_translate_safe(texts, batch_size=100):
    results = []
    total = len(texts)

    for i in range(0, total, batch_size):
        batch = texts[i:i + batch_size]
        print(f"🔄 Menerjemahkan batch {i}-{i + len(batch)} ...")
        try:
            batch_translated = []
            for text in batch:
                if not isinstance(text, str) or text.strip() == "":
                    batch_translated.append("")
                    continue
                translated = translator.translate(text)
                batch_translated.append(translated)
                time.sleep(0.3)  # jeda antar permintaan
            results.extend(batch_translated)
        except Exception as e:
            print(f"⚠️ Batch gagal diterjemahkan ({i}-{i + len(batch)}): {e}")
            # Tambahkan placeholder agar panjang tetap sama
            results.extend([""] * len(batch))
            time.sleep(5)

    return results

# Jalankan terjemahan
df["translated"] = batch_translate_safe(df["clean_text"].tolist())

# Simpan hasilnya
df.to_csv("hasil_terjemahan.csv", index=False)
print("✅ Translasi selesai dan disimpan ke 'hasil_terjemahan.csv'")
# Out:
# 🔄 Menerjemahkan batch 0-100 ...
# ...

# %% [markdown]
# # **Pengumpulan data komentar**

# %%
# Instal pustaka yang dibutuhkan
# !pip install google-api-python-client pandas

import googleapiclient.discovery
import pandas as pd

# --- KREDENSIAL API YOUTUBE ---
# Penting: Ganti 'API_KEY_KAMU' dengan kunci API YouTube-mu.
# Jangan pernah bagikan kunci API ini kepada siapa pun!
api_key = "AIzaSyBpwpNnGp7hTErrbzw7fXDaNAKyWM3IBps"
youtube = googleapiclient.discovery.build("youtube", "v3", developerKey=api_key)

# --- ID VIDEO TARGET ---
# Ganti 'VIDEO_ID_KAMU' dengan ID video 'Aura Farming Pacu Jalur' yang kamu pilih.
# ID video ada di bagian akhir URL YouTube (contoh: https://www.youtube.com/watch?v=VIDEO_ID_KAMU)
video_id = "dh5Q3suYdYs"

def get_comments(video_id):
    """Fungsi untuk mengambil semua komentar dari sebuah video."""
    all_comments = []
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        textFormat="plainText",
        maxResults=100
    )

    while request:
        response = request.execute()
        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']
            all_comments.append([
                comment['authorDisplayName'],
                comment['publishedAt'],
                comment['textDisplay'],
                comment['likeCount']
            ])

        # Lanjutkan ke halaman komentar berikutnya
        request = youtube.commentThreads().list_next(request, response)

    return pd.DataFrame(all_comments, columns=['author', 'date', 'text', 'likes'])

# Jalankan fungsi untuk mengambil data
print(f"Mengambil data komentar dari video dengan ID: {video_id}...")
df_comments = get_comments(video_id)

# Tampilkan 5 baris pertama dari data yang diambil
print("\nData komentar berhasil diambil! Berikut 5 baris pertamanya:")
print(df_comments.head())

# Simpan data ke file CSV agar bisa diolah nanti
df_comments.to_csv("komentar_aura_farming.csv", index=False)
print("\nData sudah disimpan ke file: komentar_aura_farming.csv")
# Out:
# ...
# Mengambil data komentar dari video dengan ID: dh5Q3suYdYs...
#
# Data komentar berhasil diambil! Berikut 5 baris pertamanya:
#                author                  date  \
# 0    @SajidKhan-sp1jr  2025-09-10T17:22:36Z
# 1  @AB_SHIVANSHSAXENA  2025-09-09T07:32:57Z
# 2           @Marzyart  2025-09-08T17:05:44Z
# 3       @chickio_raul  2025-09-08T00:42:06Z
# 4  @mobonlyfamily9714  2025-09-07T19:27:48Z
#
#                                                 text  likes
# 0  I still don't understand how he is gaining aur...      0
# 1                               FREE FIRE NEW EMOTE😅      0
# 2  No, the song was playing on the boat but we ca...      0
# 3                      el negrito ojo claros ozunaaa      0
# 4  I got the OG strawberry elephant by Aura farmi...      0
#
# Data sudah disimpan ke file: komentar_aura_farming.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %% [markdown]
# # Pembersihan data

# %%
# Instal pustaka emoji
# !pip install emoji

import re
import string
import pandas as pd
import emoji # Import library emoji

# Atur opsi agar pandas menampilkan semua baris dan kolom
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Muat data dari file CSV yang sudah kamu simpan
df_comments = pd.read_csv("komentar_aura_farming.csv")

def clean_text_final(text):
    """Fungsi untuk membersihkan teks secara komprehensif, termasuk emoji."""
    text = str(text)

    # 1. Hapus tautan URL
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)

    # 2. Hapus semua emoji menggunakan library 'emoji'
    text = emoji.demojize(text)
    text = re.sub(r':[a-zA-Z0-9_]+:', '', text)

    # 3. Ubah semua teks menjadi huruf kecil
    text = text.lower()

    # 4. Hapus tanda baca
    text = text.translate(str.maketrans('', '', string.punctuation))

    # 5. Hapus angka
    text = re.sub(r'\d+', '', text)

    # 6. Hapus spasi berlebihan dan trim
    text = re.sub(r'\s+', ' ', text).strip()

    return text

# Terapkan fungsi pembersihan yang diperbarui ke kolom 'text'
print("Melakukan pra-pemrosesan data secara komprehensif...")
df_comments['cleaned_text'] = df_comments['text'].apply(clean_text_final)

# Tampilkan semua baris data yang sudah bersih
print("\nData komentar setelah dibersihkan:")
print(df_comments[['text', 'cleaned_text']])

# Simpan DataFrame yang sudah diproses ke file baru
df_comments.to_csv("komentar_aura_farming_bersih_final.csv", index=False)
print("\nData yang sudah bersih (final) disimpan ke file: komentar_aura_farming_bersih_final.csv")
# Out:
# ...
# Melakukan pra-pemrosesan data secara komprehensif...
#
# Data komentar setelah dibersihkan:
#                                                   text  \
# 0    I still don't understand how he is gaining aur...
# 1                                 FREE FIRE NEW EMOTE😅
# 2    No, the song was playing on the boat but we ca...
# 3                        el negrito ojo claros ozunaaa
# 4    I got the OG strawberry elephant by Aura farmi...
# 5    a guy in Australia is doing this right now hah...
# 6                Today rip boy news tru wa are fake ja
# 7                                     😎 that kid\n🤓 me
# 8                                   That ent aura farm
# 9                                         Lame fake ai
# 10   The dance is bullshit and the edit music but i...
# 11                          Original had way more Aura
# 12                                     Absolute sinema
# 13   Pata nahi isme konsi badi baat hai ki duniya i...
# ...

# %% [markdown]
# # Translate

# %%
# Instal pustaka yang dibutuhkan
# !pip install googletrans==4.0.0-rc1

import pandas as pd
from googletrans import Translator

# Muat data yang sudah dibersihkan dari langkah sebelumnya
df_comments = pd.read_csv("komentar_aura_farming_bersih_final.csv")

# Inisialisasi penerjemah
translator = Translator()

# Fungsi untuk menerjemahkan teks
def translate_text(text):
    """Menerjemahkan teks ke Bahasa Inggris, melewati teks kosong atau non-string."""
    if pd.isna(text) or not isinstance(text, str) or len(text.strip()) == 0:
        return ""
    try:
        # Menentukan bahasa sumber secara otomatis dan menerjemahkan ke Inggris
        return translator.translate(text, dest='en').text
    except Exception as e:
        print(f"Error menerjemahkan: {e}")
        return ""

# Terapkan fungsi penerjemahan ke kolom 'cleaned_text'
print("Melakukan penerjemahan komentar...")
df_comments['translated_text'] = df_comments['cleaned_text'].apply(translate_text)

# Tampilkan beberapa komentar yang sudah diterjemahkan
print("\nBeberapa komentar setelah diterjemahkan ke Bahasa Inggris:")
print(df_comments[['text', 'cleaned_text', 'translated_text']].head(10))

# Simpan data yang sudah diterjemahkan
df_comments.to_csv("komentar_aura_farming_translated.csv", index=False)
print("\nData dengan kolom terjemahan sudah disimpan.")
# Out:
# ...
# Melakukan penerjemahan komentar...
# Error menerjemahkan: 'Translator' object has no attribute 'raise_Exception'
# Error menerjemahkan: 'Translator' object has no attribute 'raise_Exception'
# Error menerjemahkan: 'Translator' object has no attribute 'raise_Exception'
# Error menerjemahkan: 'Translator' object has no attribute 'raise_Exception'
# Error menerjemahkan: 'Translator' object has no attribute 'raise_Exception'
# Error menerjemahkan: 'Translator' object has no attribute 'raise_Exception'
# Error menerjemahkan: 'Translator' object has no attribute 'raise_Exception'
# Error menerjemahkan: 'Translator' object has no attribute 'raise_Exception'
# Error menerjemahkan: 'Translator' object has no attribute 'raise_Exception'
# Error menerjemahkan: 'Translator' object has no attribute 'raise_Exception'
# Error menerjemahkan: 'Translator' object has no attribute 'raise_Exception'
# Error menerjemahkan: 'Translator' object has no attribute 'raise_Exception'
# ...

# %%
# Instal pustaka yang dibutuhkan
# !pip install nltk

import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd

# Atur opsi agar pandas menampilkan semua baris dan kolom
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Unduh kamus VADER yang diperlukan
# Ini hanya perlu dilakukan sekali
nltk.download('vader_lexicon')

# Muat data yang sudah dibersihkan dari langkah sebelumnya
df_comments = pd.read_csv("komentar_aura_farming_bersih_final.csv")

# Inisialisasi VADER Sentiment Analyzer
analyzer = SentimentIntensityAnalyzer()

# Fungsi untuk mengklasifikasikan sentimen
def classify_sentiment(text):
    """
    Mengklasifikasikan sentimen berdasarkan skor VADER.
    Skor 'compound' > 0.05 dianggap Positif.
    Skor 'compound' < -0.05 dianggap Negatif.
    Selain itu, dianggap Netral.
    """
    if pd.isna(text):
        return 'Netral'

    score = analyzer.polarity_scores(text)
    compound_score = score['compound']

    if compound_score > 0.05:
        return 'Positif'
    elif compound_score < -0.05:
        return 'Negatif'
    else:
        return 'Netral'

# Terapkan fungsi ke kolom 'cleaned_text'
print("Melakukan analisis sentimen pada data yang sudah bersih...")
df_comments['sentiment'] = df_comments['cleaned_text'].apply(classify_sentiment)

# Tampilkan semua baris data dengan label sentimen
# Perhatikan, `.head(10)` sudah dihapus
print("\nData komentar dengan label sentimen:")
print(df_comments[['text', 'cleaned_text', 'sentiment']])

# Hitung jumlah total sentimen
sentiment_counts = df_comments['sentiment'].value_counts()
print("\nRingkasan total sentimen:")
print(sentiment_counts)

# Simpan DataFrame yang sudah ada kolom sentimennya
df_comments.to_csv("komentar_aura_farming_sentimen.csv", index=False)
print("\nData dengan sentimen sudah disimpan ke: komentar_aura_farming_sentimen.csv")
# Out:
# ...
# Melakukan analisis sentimen pada data yang sudah bersih...
#
# Data komentar dengan label sentimen:
#                                                   text  \
# 0    I still don't understand how he is gaining aur...
# 1                                 FREE FIRE NEW EMOTE😅
# 2    No, the song was playing on the boat but we ca...
# 3                        el negrito ojo claros ozunaaa
# 4    I got the OG strawberry elephant by Aura farmi...
# 5    a guy in Australia is doing this right now hah...
# 6                Today rip boy news tru wa are fake ja
# 7                                     😎 that kid\n🤓 me
# 8                                   That ent aura farm
# 9                                         Lame fake ai
# 10   The dance is bullshit and the edit music but i...
# 11                          Original had way more Aura
# 12                                     Absolute sinema
# 13   Pata nahi isme konsi badi baat hai ki duniya i...
# ...

# %%
# Instal pustaka yang dibutuhkan untuk visualisasi
# !pip install matplotlib seaborn wordcloud

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# Muat data yang sudah memiliki kolom sentimen
df_comments = pd.read_csv("komentar_aura_farming_sentimen.csv")

# Pastikan kolom 'date' dalam format datetime
df_comments['date'] = pd.to_datetime(df_comments['date'])

# Atur style visualisasi
sns.set_style("whitegrid")
plt.style.use('seaborn-v0_8-darkgrid')
